# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_table('./acc-loss-mobilenet.txt',names=['acc','loss','valacc','valloss'],sep=' ')

# %%
df
# Out:
#        acc    loss  valacc  valloss
# 0   0.5003  0.7697  0.3269   0.8945
# 1   0.3469  0.8630  0.2252   0.9375
# 2   0.2752  0.8959  0.1789   0.9468
# 3   0.2266  0.9147  0.1563   0.9556
# 4   0.2127  0.9191  0.1403   0.9575
# 5   0.1940  0.9266  0.1265   0.9639
# 6   0.1862  0.9269  0.1069   0.9688
# 7   0.1690  0.9353  0.1082   0.9644
# 8   0.1603  0.9408  0.1002   0.9727
# 9   0.1558  0.9405  0.0996   0.9673
# 10  0.1458  0.9453  0.1010   0.9658
# 11  0.1412  0.9445  0.0811   0.9775
# 12  0.1437  0.9435  0.0899   0.9702
# 13  0.1402  0.9456  0.0779   0.9746
# 14  0.1361  0.9471  0.0832   0.9731
# 15  0.1314  0.9525  0.0890   0.9712
# 16  0.1251  0.9530  0.0813   0.9746
# 17  0.1365  0.9448  0.0756   0.9780
# 18  0.1255  0.9497  0.0783   0.9746
# 19  0.1209  0.9550  0.0726   0.9746
# 20  0.1218  0.9520  0.0862   0.9663
# 21  0.1195  0.9507  0.0723   0.9790
# 22  0.1192  0.9514  0.0704   0.9771
# 23  0.1193  0.9547  0.0780   0.9746
# 24  0.1123  0.9571  0.0658   0.9775
# ...
