# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_table('./acc-loss-vgg.txt',names=['acc','loss','valacc','valloss'],sep=' ')

# %%
df
# Out:
#        acc    loss  valacc  valloss
# 0   0.5817  0.9553  0.5809   0.9440
# 1   0.5247  0.9563  0.5389   0.9445
# 2   0.4820  0.9613  0.5038   0.9490
# 3   0.4531  0.9635  0.4912   0.9475
# 4   0.4309  0.9662  0.4765   0.9470
# 5   0.4024  0.9725  0.4447   0.9500
# 6   0.3946  0.9688  0.4374   0.9515
# 7   0.3805  0.9682  0.4186   0.9540
# 8   0.3555  0.9737  0.4247   0.9470
# 9   0.3527  0.9708  0.4218   0.9410
# 10  0.3283  0.9783  0.3987   0.9485
# 11  0.3212  0.9770  0.3989   0.9495
# 12  0.3026  0.9825  0.3909   0.9500
# 13  0.2949  0.9815  0.3860   0.9525
# 14  0.2859  0.9818  0.4193   0.9410
# 15  0.2769  0.9835  0.3772   0.9480
# 16  0.2734  0.9802  0.4229   0.9380
# 17  0.2689  0.9803  0.3450   0.9525
# 18  0.2488  0.9858  0.3370   0.9520
# 19  0.2458  0.9833  0.3436   0.9525
# 20  0.2436  0.9827  0.3387   0.9500
# 21  0.2377  0.9845  0.3330   0.9535
# 22  0.2252  0.9872  0.3467   0.9500
# 23  0.2195  0.9878  0.3558   0.9480
# 24  0.2153  0.9855  0.3196   0.9525
# ...

# %%
acc_vgg=list(np.array(df['acc']))

# %%
acc_vgg
# Out:
# [0.5817,
#  0.5247,
#  0.482,
#  0.4531,
#  0.4309,
#  0.4024,
#  0.3946,
#  0.3805,
#  0.3555,
#  0.3527,
#  0.3283,
#  0.3212,
#  0.3026,
#  0.2949,
#  0.2859,
#  0.2769,
#  0.2734,
#  0.2689,
#  0.2488,
#  0.2458,
#  0.2436,
#  0.2377,
#  0.2252,
#  0.2195,
#  0.2153,
#  0.2039,
#  0.2127,
#  0.1969,
#  0.1903,
#  0.185,
#  0.1874,
#  0.1811,
#  0.1783,
#  0.1696,
#  0.1695,
#  0.1602,
#  0.1589,
#  0.1537,
#  0.1475,
#  0.1461,
#  0.1452,
#  0.1402,
#  0.1379,
#  0.1393,
#  0.1274,
#  0.1288,
#  0.1274,
#  0.122,
#  0.1187,
#  0.1117]
